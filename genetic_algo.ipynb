# %%
#pip3 install sklearn-genetic

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
import csv
from sklearn.svm import SVC
from genetic_selection import GeneticSelectionCV
from sklearn.metrics import classification_report, confusion_matrix

data = pd.read_csv(r'50F.csv')

print(data.dtypes)

print(data.shape)
lbl = data['Type'].value_counts()
print(lbl)
data.replace([np.inf, -np.inf], np.nan, inplace=True)
data.replace([np.inf, -np.inf], np.nan, inplace=True)
print("***********")
data = data.drop(['URLs', 'Type'], axis=1)

data = data.reset_index()
print(data.shape)
print(data.columns)
# np.any(np.isnan(data))

X = data.iloc[:, 2:]
print(X.head())
print(type(X))

X = np.nan_to_num(X.astype(np.float32))
print(type(X))
Y = data['Label']

'''
def main():
    estimator = SVC(kernel='rbf', C=1,gamma='auto')
    #estimator = linear_model.LogisticRegression(solver="liblinear", multi_class="ovr")
    featureslist1=[]

    #for i in range(0,10):
    selector = GeneticSelectionCV(estimator,
                                  cv=5,
                                  verbose=1,
                                  scoring="accuracy",
                                  n_population=50,
                                  crossover_proba=0.5,
                                  mutation_proba=0.2,
                                  n_generations=10,
                                  crossover_independent_proba=0.5,
                                  mutation_independent_proba=0.05,
                                  tournament_size=3,
                                  n_gen_no_change=10,
                                  caching=True,
                                  n_jobs=-1)
    selector = selector.fit(X, Y)
    print(selector.support_)

if __name__ == "__main__":
    main()
    '''
'''
y_pred = selector.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
total1=sum(sum(cm))
accuracy1=(cm[0,0]+cm[1,1])/total1
print ('Accuracy : ', accuracy1)
print ( 'number of valid variables:', selector.n_features_)
genfeats =X_train.columns[selector.support_]
genfeats = list(genfeats)
print("Chosen Feats:  ", genfeats)
featureslist1.extend(genfeats)
'''
# Out:
# URLs                 object
# Type                 object
# Label                 int64
# ip_DNS                int64
# url_len               int64
# Dots Count            int64
# Dots_domain           int64
# hyphen_domain         int64
# Count_&               int64
# Count_;               int64
# Count_http            int64
# alphabets_url         int64
# lower_case_letter     int64
# Count_b               int64
# Count_g               int64
# Count_l               int64
# Count_www             int64
# dtype: object
# (199997, 17)
# Type
# benign       99999
# malicious    99998
# Name: count, dtype: int64
# ***********
# (199997, 16)
# Index(['index', 'Label', 'ip_DNS', 'url_len', 'Dots Count', 'Dots_domain',
#        'hyphen_domain', 'Count_&', 'Count_;', 'Count_http', 'alphabets_url',
#        'lower_case_letter', 'Count_b', 'Count_g', 'Count_l', 'Count_www'],
#       dtype='object')
#    ip_DNS  url_len  Dots Count  Dots_domain  hyphen_domain  Count_&  Count_;  \
# 0       0       38           1            1              0        0        0
# 1       0      118           1            1              0        0        0
# 2       0       52           2            2              0        0        0
# 3       0       53           1            1              0        0        0
# 4       0       52           1            1              0        0        0
#
#    Count_http  alphabets_url  lower_case_letter  Count_b  Count_g  Count_l  \
# 0           1             29                 29        1        1        0
# 1           1             93                 93        2        1        9
# 2           1             35                 35        2        1        1
# 3           1             44                 44        1        0        2
# 4           1             37                 37        1        0        3
#
#    Count_www
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>
# '\ny_pred = selector.predict(X_test)\nfrom sklearn.metrics import classification_report, confusion_matrix\ncm=confusion_matrix(Y_test,y_pred)\nprint(cm)\ntotal1=sum(sum(cm))\naccuracy1=(cm[0,0]+cm[1,1])/total1\nprint (\'Accuracy : \', accuracy1)\nprint ( \'number of valid variables:\', selector.n_features_)\ngenfeats =X_train.columns[selector.support_]\ngenfeats = list(genfeats)\nprint("Chosen Feats:  ", genfeats)\nfeatureslist1.extend(genfeats)\n'

# %%
X.shape

# %%
Y.shape

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3,
                                                    random_state=109)  # 70% training and 30% test

# %%
estimator = linear_model.LogisticRegression(solver="liblinear", multi_class="ovr")
featureslist1=[]

# %%
featureslist1
# Out:
# []

# %%
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from genetic_selection import GeneticSelectionCV
from sklearn.svm import SVC

# %%
selector = GeneticSelectionCV(estimator,
                                  cv=5,
                                  verbose=1,
                                  scoring="accuracy",
                                  n_population=50,
                                  crossover_proba=0.5,
                                  mutation_proba=0.2,
                                  n_generations=10,
                                  crossover_independent_proba=0.5,
                                  mutation_independent_proba=0.05,
                                  tournament_size=3,
                                  n_gen_no_change=10,
                                  caching=True,
                                  n_jobs=-1)
selector = selector.fit(X_train, Y_train)
y_pred = selector.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
cm=confusion_matrix(Y_test,y_pred)
print(cm)
total1=sum(sum(cm))
accuracy1=(cm[0,0]+cm[1,1])/total1
print ('Accuracy : ', accuracy1)
print ( 'number of valid variables:', selector.n_features_)
genfeats =X_train.columns[selector.support_]
genfeats = list(genfeats)
print("Chosen Feats:  ", genfeats)
featureslist1.extend(genfeats)
